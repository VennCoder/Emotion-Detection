# %% [markdown]
# ## Import the Necessary Libraries

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Dropout, Flatten
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Prepare the Dataset

# %%
train_datagen = ImageDataGenerator(
    rescale = 1 / 255.,
    zoom_range = 0.1,
    shear_range = 0.1,
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    fill_mode = 'nearest'
)

valid_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_dataset = train_datagen.flow_from_directory(
    '/kaggle/input/fer2013/train',
    target_size = (48, 48),
    batch_size = 32,
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle = True
)

valid_dataset = valid_datagen.flow_from_directory(
    '/kaggle/input/fer2013/test',
    target_size = (48, 48),
    batch_size = 32,
    color_mode = 'grayscale',
    class_mode = 'categorical',
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ## Define the Model

# %%
inputs = tf.keras.Input(shape=(48, 48, 1))
x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
x = MaxPool2D()(inputs)
x = Conv2D(64, 3, activation='relu', padding='same')(x)
x = MaxPool2D()(x)
x = Conv2D(128, 3, activation='relu', padding='same')(x)
x = MaxPool2D()(x)
x = Conv2D(256, 3, activation='relu', padding='same')(x)
x = MaxPool2D()(x)
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dense(7, activation='softmax')(x)

model = Model(inputs=inputs, outputs=x)

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy']
)

learning_rate = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.3)

# %% [markdown]
# ## Train the Model

# %%
history = model.fit(train_dataset, validation_data=valid_dataset, epochs=40, callbacks=[learning_rate])
# Out:
# Epoch 1/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.5437 - loss: 1.1943 - val_accuracy: 0.5089 - val_loss: 1.2865 - learning_rate: 0.0010
# Epoch 2/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.5481 - loss: 1.1839 - val_accuracy: 0.5354 - val_loss: 1.2349 - learning_rate: 0.0010
# Epoch 3/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.5493 - loss: 1.1912 - val_accuracy: 0.5252 - val_loss: 1.2630 - learning_rate: 0.0010
# Epoch 4/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 44s 48ms/step - accuracy: 0.5581 - loss: 1.1656 - val_accuracy: 0.5316 - val_loss: 1.2540 - learning_rate: 0.0010
# Epoch 5/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 43s 47ms/step - accuracy: 0.5571 - loss: 1.1691 - val_accuracy: 0.5357 - val_loss: 1.2452 - learning_rate: 0.0010
# Epoch 6/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.5743 - loss: 1.1221 - val_accuracy: 0.5522 - val_loss: 1.2053 - learning_rate: 3.0000e-04
# Epoch 7/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.5844 - loss: 1.0917 - val_accuracy: 0.5566 - val_loss: 1.1955 - learning_rate: 3.0000e-04
# Epoch 8/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 43s 48ms/step - accuracy: 0.5934 - loss: 1.0745 - val_accuracy: 0.5571 - val_loss: 1.1951 - learning_rate: 3.0000e-04
# Epoch 9/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.5920 - loss: 1.0780 - val_accuracy: 0.5556 - val_loss: 1.2077 - learning_rate: 3.0000e-04
# Epoch 10/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.5973 - loss: 1.0730 - val_accuracy: 0.5582 - val_loss: 1.2119 - learning_rate: 3.0000e-04
# Epoch 11/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 43s 47ms/step - accuracy: 0.6025 - loss: 1.0602 - val_accuracy: 0.5578 - val_loss: 1.2192 - learning_rate: 3.0000e-04
# Epoch 12/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.5990 - loss: 1.0499 - val_accuracy: 0.5598 - val_loss: 1.2035 - learning_rate: 9.0000e-05
# Epoch 13/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.6144 - loss: 1.0325 - val_accuracy: 0.5591 - val_loss: 1.2002 - learning_rate: 9.0000e-05
# Epoch 14/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 44s 49ms/step - accuracy: 0.6113 - loss: 1.0304 - val_accuracy: 0.5655 - val_loss: 1.1959 - learning_rate: 9.0000e-05
# Epoch 15/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 43s 48ms/step - accuracy: 0.6147 - loss: 1.0188 - val_accuracy: 0.5634 - val_loss: 1.1947 - learning_rate: 2.7000e-05
# Epoch 16/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.6149 - loss: 1.0207 - val_accuracy: 0.5624 - val_loss: 1.1956 - learning_rate: 2.7000e-05
# Epoch 17/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - accuracy: 0.6165 - loss: 1.0176 - val_accuracy: 0.5651 - val_loss: 1.1952 - learning_rate: 2.7000e-05
# Epoch 18/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 43s 47ms/step - accuracy: 0.6149 - loss: 1.0176 - val_accuracy: 0.5655 - val_loss: 1.1953 - learning_rate: 2.7000e-05
# Epoch 19/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 44s 49ms/step - accuracy: 0.6182 - loss: 1.0118 - val_accuracy: 0.5630 - val_loss: 1.1952 - learning_rate: 8.1000e-06
# Epoch 20/20
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.6168 - loss: 1.0170 - val_accuracy: 0.5635 - val_loss: 1.1946 - learning_rate: 8.1000e-06

# %%
plt.figure()
plt.title('Train and Validation Accuracy')
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()

plt.figure()
plt.title('Train and Validation Loss')
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
imgs, labels = next(valid_dataset)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(10, 3))
for i in range(5):
    image = np.expand_dims(imgs[i], axis=0)
    predict = model.predict(image)[0].argmax()
    label = np.argmax(labels[i], axis=0)
    
    axes[i].imshow(imgs[i], cmap='gray')
    axes[i].set_title(f'Truth: {label}, Predict: {predict}')
    axes[i].axis('off')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
